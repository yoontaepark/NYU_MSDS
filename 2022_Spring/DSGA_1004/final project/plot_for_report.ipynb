# %% [markdown]
# ## Plots for report

# %%
## hyper parameter selection
import matplotlib.pyplot as plt
max_iteration = [5, 10, 15]

### small
s_val_score_50_1e05 = [0.0577075234606336, 0.0635895352944341, 0.0650956254033912]
s_val_score_50_5e05 = [0.0621917669922812, 0.0660968390698916, 0.0690043543597796]
s_val_score_50_1e04 = [0.0618452982550493, 0.0639129112934431, 0.0710234947426728]
s_val_score_50_5e04 = [0.0630446605035952, 0.0672379179092334, 0.0697269876953358]

s_val_score_100_1e05 = [0.105957735791259, 0.103744343372548, 0.102407005393966]
s_val_score_100_5e05 = [0.104072890852262, 0.104111588033438, 0.102851053285498]
s_val_score_100_1e04 = [0.105618268994141, 0.105083444700799, 0.104622195435061]
s_val_score_100_5e04 = [0.0908095349081199, 0.0859637120598874, 0.0839506527355752]

s_val_score_200_1e05 = [0.101191168433145, 0.0980592295120011, 0.0953594526802997]
s_val_score_200_5e05 = [0.0948979268089694, 0.093175554296234, 0.0924394713585421]
s_val_score_200_1e04 = [0.0925242242230887, 0.0916504598308811, 0.0909401625613334]
s_val_score_200_5e04 = [0.0860084285064337, 0.0876267423812164, 0.0846561248850879]

### large
l_val_score_100_1e03 = [0.000511040583560073, 0.00111133576156659, 0.00184508258720035]
l_val_score_100_5e03 = [0.00166969232468671, 0.00687578362343239, 0.0117517425392572]
l_val_score_100_1e02 = [0.00364468138030288, 0.0148192933896755, 0.0223268095779755]
l_val_score_100_5e02 = [0.00427680477454516, 0.018041818333233, 0.025868350743738]

l_val_score_200_1e03 = [0.00678574788403044, 0.010998564717602, 0.0144509095048147]
l_val_score_200_5e03 = [0.0125633461590922, 0.0213412432057856, 0.0280847703754576]
l_val_score_200_1e02 = [0.00364467491144424, 0.0148191474744148, 0.0223268200274928]
l_val_score_200_5e02 = [0.00584559638772102, 0.02100610938936, 0.0301614345436209]

l_val_score_300_1e03 = [0.0195936298347548, 0.0272169089951994, 0.0299862874948167]
l_val_score_300_5e03 = [0.0252678316716799, 0.0307052325293919, 0.0349090937649444]
l_val_score_300_1e02 = [0.0171604899671496, 0.0348445564814197, 0.0415544526529172]
l_val_score_300_5e02 = [0.00649806275206334, 0.021907562041566, 0.0314936636116647]

# %%
# plotting the result
plt.title('NDCG score for small dataset, rank=50')
plt.plot(max_iteration, s_val_score_50_1e05, marker = 's', label = 'reg_param: 1e-05')
plt.plot(max_iteration, s_val_score_50_5e05, marker = 's', color = 'g', label = 'reg_param: 5e-05')
plt.plot(max_iteration, s_val_score_50_1e04, marker = 's', color = 'r', label = 'reg_param: 1e-04')
plt.plot(max_iteration, s_val_score_50_5e04, marker = 's', color = 'k', label = 'reg_param: 5e-04')
plt.xlabel('Max Iteration')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
# plotting the result

plt.title('NDCG score for small dataset, rank=100')
plt.plot(max_iteration, s_val_score_100_1e05, marker = 's', label = 'reg_param: 1e-05')
plt.plot(max_iteration, s_val_score_100_5e05, marker = 's', color = 'g', label = 'reg_param: 5e-05')
plt.plot(max_iteration, s_val_score_100_1e04, marker = 's', color = 'r', label = 'reg_param: 1e-04')
plt.plot(max_iteration, s_val_score_100_5e04, marker = 's', color = 'k', label = 'reg_param: 5e-04')
plt.xlabel('Max Iteration')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
# plotting the result
plt.title('NDCG score for small dataset, rank=200')
plt.plot(max_iteration, s_val_score_200_1e05, marker = 's', label = 'reg_param: 1e-05')
plt.plot(max_iteration, s_val_score_200_5e05, marker = 's', color = 'g', label = 'reg_param: 5e-05')
plt.plot(max_iteration, s_val_score_200_1e04, marker = 's', color = 'r', label = 'reg_param: 1e-04')
plt.plot(max_iteration, s_val_score_200_5e04, marker = 's', color = 'k', label = 'reg_param: 5e-04')
plt.xlabel('Max Iteration')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
# plotting the result
plt.title('NDCG score for large dataset, rank=100')
plt.plot(max_iteration, l_val_score_100_1e03, marker = 's', label = 'reg_param: 0.001')
plt.plot(max_iteration, l_val_score_100_5e03, marker = 's', color = 'g', label = 'reg_param: 0.005')
plt.plot(max_iteration, l_val_score_100_1e02, marker = 's', color = 'r', label = 'reg_param: 0.01')
plt.plot(max_iteration, l_val_score_100_5e02, marker = 's', color = 'k', label = 'reg_param: 0.05')
plt.xlabel('Max Iteration')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
# plotting the result
plt.title('NDCG score for large dataset, rank=200')
plt.plot(max_iteration, l_val_score_200_1e03, marker = 's', label = 'reg_param: 0.001')
plt.plot(max_iteration, l_val_score_200_5e03, marker = 's', color = 'g', label = 'reg_param: 0.005')
plt.plot(max_iteration, l_val_score_200_1e02, marker = 's', color = 'r', label = 'reg_param: 0.01')
plt.plot(max_iteration, l_val_score_200_5e02, marker = 's', color = 'k', label = 'reg_param: 0.05')
plt.xlabel('Max Iteration')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
# plotting the result
plt.title('NDCG score for large dataset, rank=300')
plt.plot(max_iteration, l_val_score_300_1e03, marker = 's', label = 'reg_param: 0.001')
plt.plot(max_iteration, l_val_score_300_5e03, marker = 's', color = 'g', label = 'reg_param: 0.005')
plt.plot(max_iteration, l_val_score_300_1e02, marker = 's', color = 'r', label = 'reg_param: 0.01')
plt.plot(max_iteration, l_val_score_300_5e02, marker = 's', color = 'k', label = 'reg_param: 0.05')
plt.xlabel('Max Iteration')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %% [markdown]
# ## Plot for lenskit

# %%
import matplotlib.pyplot as plt
max_iteration = [5, 10, 15]
len_s_val_score_100_1e04 = [0.0596148668756741, 0.0581208625180163, 0.056810394150239]
len_l_val_score_300_1e04 = [0.0283363296627175, 0.025909208272376, 0.0254438621689313]

# %%
# plotting the result
plt.title('LensKit: NDCG on best hyper parameters(val score)')
plt.plot(max_iteration, len_s_val_score_100_1e04, marker = 's', label = 'small')
plt.plot(max_iteration, len_l_val_score_300_1e04, marker = 's', color = 'g', label = 'large')
plt.xlabel('Max Iteration')
plt.ylabel('NDCG')
plt.legend()
plt.show()
